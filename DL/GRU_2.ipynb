# %% [markdown]
# <a href="https://colab.research.google.com/github/Maram00ali/REV4RE/blob/main/GRU_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import necessary Packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
from sklearn import feature_extraction, model_selection, naive_bayes, metrics, svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
# %matplotlib inline

# %% [markdown]
# **Read the data using pandas framework with column names label and message**

# %%
dataset = pd.read_csv('dataset path')

# %% [markdown]
# Display first five rows from the dataset

# %%
dataset.head()
# Out:
#                                               Review  RivewRelevance
# 0                                    5 star good app               1
# 1                A monthly subscription fee. Really?               1
# 2  Able to customize and decorate a ton of things...               1
# 3           All I can say is this game is the best!!               1
# 4  Although not the best, it better for own creat...               1

# %% [markdown]
# **Based on the labels, the number of ham & spam messages are counted and plotted**

# %%
dataset.groupby('RivewRelevance').describe()
# Out:
#                Review         \
#                 count unique
# RivewRelevance
# 0               10352  10349
# 1               69045  68658
# 2                5535   5535
#
#
#                                                               top freq
# RivewRelevance
# 0                                                 I am very happy    3
# 1                                                 I love this app   10
# 2               This messenger app cleanly outranks other simi...    1

# %%
dataset.RivewRelevance.value_counts()
# Out:
# 1    69045
# 0    10352
# 2     5535
# Name: RivewRelevance, dtype: int64

# %%
count_Class=pd.value_counts(dataset["RivewRelevance"], sort= True)
count_Class.plot(kind = 'bar',color = ["green","red","yellow"])
plt.title('Bar Plot')
plt.show()

# %%
#dataset['RivewRelevance'] = dataset['RivewRelevance'].map( {'relevent': '1', 'irrelevent': 0, 'mix' : 2 } )

# %%
dataset.head()
# Out:
#                                               Review  RivewRelevance
# 0                                    5 star good app               1
# 1                A monthly subscription fee. Really?               1
# 2  Able to customize and decorate a ton of things...               1
# 3           All I can say is this game is the best!!               1
# 4  Although not the best, it better for own creat...               1

# %% [markdown]
# **Put different Labels in separate pandas dataframe inorder to generate WORDCLOUD**

# %%
data_relevent  = dataset[dataset['RivewRelevance'] == 1].copy()
data_irrelevnt = dataset[dataset['RivewRelevance'] == 0].copy()
data_mix = dataset[dataset['RivewRelevance'] == 2].copy()

# %%
# !pip install wordcloud==1.8.2.2
# Out:
# Collecting wordcloud==1.8.2.2
#   Downloading wordcloud-1.8.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.6/458.6 KB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.8.2.2) (1.23.4)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.8.2.2) (3.6.0)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.8.2.2) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (4.37.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.8.2.2) (1.0.5)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud==1.8.2.2) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import wordcloud
from wordcloud import WordCloud
def show_wordcloud(df, title):
    text = ' '.join(df['Review'].astype(str).tolist())
    stopwords = set(wordcloud.STOPWORDS)

    fig_wordcloud = wordcloud.WordCloud(stopwords=stopwords,background_color='lightgrey',
                    colormap='viridis', width=800, height=600).generate(text)

    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud)
    plt.axis('off')
    plt.title(title, fontsize=20 )
    plt.show()

# %%
show_wordcloud(data_relevent, "Reivew Relevance")

# %%
show_wordcloud(data_irrelevnt, "Reivew Relevance")

# %%
show_wordcloud(data_mix, "Reivew Relevance")

# %% [markdown]
# **Import Necessary for text preprocessing & Training**

# %%
# helps in text preprocessing
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# helps in model building
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.callbacks import EarlyStopping

# split data into train and test set
from sklearn.model_selection import train_test_split
# Out:
# 2023-04-27 04:50:19.405776: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 04:50:19.536068: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-27 04:50:19.543268: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-27 04:50:19.543287: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-27 04:50:19.581004: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-04-27 04:50:21.072975: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 04:50:21.073054: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 04:50:21.073063: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# **Dataset split into Train & Test**

# %%
# Importing NLTK Libraries
import nltk
from nltk.corpus import stopwords
from nltk import *

# %%
# Declaring function for text preprocessing

def preprocess_text(main_df):
  df_1 = main_df.copy()

  # remove stopwords
  nltk.download('stopwords')         # Downloading stopwords
  stop = stopwords.words('english')
  df_1['Review'] = df_1['Review'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

  # remove punctuations and convert to lower case
  #df_1['Review'] = df_1['Review'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))

  # remove double spaces
  #df_1['Review'] = df_1['Review'].apply(lambda x: re.sub(' ', ' ', x))

  return df_1

# %%
# Preprocessing training and test data
dataset['Review'] = preprocess_text(dataset)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
X = dataset['Review'].values
y = dataset['RivewRelevance'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# **Text Pre-Processing**
#
# **1. Tokenization**
#
# **2. Text Encoding**
#
# **3. Padding**

# %%
t = Tokenizer()
t.fit_on_texts(X_train)

# %%
encoded_train = t.texts_to_sequences(X_train)
encoded_test = t.texts_to_sequences(X_test)
print(encoded_train[0:2])
# Out:
# [[10, 2, 380, 9501, 3433, 12, 763, 2090, 3433, 691, 1606], [1, 521, 15805, 262, 37, 2314, 91, 26, 8207, 22, 153, 60, 2314, 5, 37, 262, 399, 1092, 218]]

# %%
max_length = 8
padded_train = pad_sequences(encoded_train, maxlen=max_length, padding='post')
padded_test = pad_sequences(encoded_test, maxlen=max_length, padding='post')
print(padded_train)
# Out:
# [[9501 3433   12 ... 3433  691 1606]
#  [  60 2314    5 ...  399 1092  218]
#  [   3 1221   46 ...  229 2415  662]
#  ...
#  [  13   17    9 ...    0    0    0]
#  [ 246  157  527 ...   86  613  527]
#  [   6   69  131 ...    0    0    0]]

# %% [markdown]
# **Model is Built with vocabulary size as the input size.**
#
# **Model is compiled and summary generated**

# %%
import tensorflow as tf
from tensorflow.keras.layers import LSTM, GRU, Dense, Embedding, Dropout

# %%
vocab_size = len(t.word_index) + 1
# define the model
gru_model = Sequential()
gru_model.add(Embedding(vocab_size,24 , trainable = False))
gru_model.add(GRU(128, return_sequences=False))
gru_model.add(Dropout(0.5))
gru_model.add(Dense(1, activation = 'sigmoid'))
# compile the model
gru_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize the model
print(gru_model.summary())
# Out:
# 2023-04-27 04:50:34.511311: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-27 04:50:34.511349: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-27 04:50:34.511369: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-378be7ce-053e-4e53-a8d7-d43f011c835b): /proc/driver/nvidia/version does not exist
# 2023-04-27 04:50:34.511794: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 24)          937584
#
#  gru (GRU)                   (None, 128)               59136
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 996,849
# Trainable params: 59,265
# Non-trainable params: 937,584
# _________________________________________________________________
# None

# %% [markdown]
# **Model is trained and validated for test dataset with 50 epochs.**
#
# **Callback is made at an early stage when the validation loss has its first minimum value.**

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# fit the model
gru_model.fit(x=padded_train,
         y=y_train,
         epochs=100,
         validation_data=(padded_test, y_test), verbose=1,
         callbacks=[early_stop]
         )
# Out:
# Epoch 1/100
# 2124/2124 [==============================] - 23s 10ms/step - loss: 0.1951 - accuracy: 0.8135 - val_loss: 0.2171 - val_accuracy: 0.8093
# Epoch 2/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: 0.1199 - accuracy: 0.8125 - val_loss: 0.0773 - val_accuracy: 0.8081
# Epoch 3/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.0102 - accuracy: 0.8113 - val_loss: -0.1123 - val_accuracy: 0.8093
# Epoch 4/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.0566 - accuracy: 0.8076 - val_loss: -0.1683 - val_accuracy: 0.8089
# Epoch 5/100
# 2124/2124 [==============================] - 18s 8ms/step - loss: -0.1670 - accuracy: 0.8046 - val_loss: -0.3541 - val_accuracy: 0.8087
# Epoch 6/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -0.3678 - accuracy: 0.7996 - val_loss: -0.2273 - val_accuracy: 0.8092
# Epoch 7/100
# 2124/2124 [==============================] - 18s 8ms/step - loss: -0.4161 - accuracy: 0.7986 - val_loss: 0.0595 - val_accuracy: 0.8090
# Epoch 8/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.6051 - accuracy: 0.7954 - val_loss: -0.7299 - val_accuracy: 0.8080
# Epoch 9/100
# 2124/2124 [==============================] - 17s 8ms/step - loss: -0.6597 - accuracy: 0.7951 - val_loss: -0.9785 - val_accuracy: 0.8056
# Epoch 10/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.4143 - accuracy: 0.7910 - val_loss: -0.4295 - val_accuracy: 0.8066
# Epoch 11/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -0.6937 - accuracy: 0.7954 - val_loss: -0.3793 - val_accuracy: 0.8093
# Epoch 12/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.1156 - accuracy: 0.7965 - val_loss: -0.3616 - val_accuracy: 0.8087
# Epoch 13/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: 0.7142 - accuracy: 0.7988 - val_loss: -0.3070 - val_accuracy: 0.8077
# Epoch 14/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.2420 - accuracy: 0.8004 - val_loss: -0.2892 - val_accuracy: 0.8084
# Epoch 15/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.6584 - accuracy: 0.7931 - val_loss: -0.8686 - val_accuracy: 0.8092
# Epoch 16/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -1.1313 - accuracy: 0.7911 - val_loss: -0.7253 - val_accuracy: 0.8083
# Epoch 17/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -1.4379 - accuracy: 0.7922 - val_loss: -1.1151 - val_accuracy: 0.8073
# Epoch 18/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -1.7867 - accuracy: 0.7915 - val_loss: -1.5011 - val_accuracy: 0.8069
# Epoch 19/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -0.9571 - accuracy: 0.7939 - val_loss: -0.9276 - val_accuracy: 0.8040
# Epoch 20/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -1.6973 - accuracy: 0.7868 - val_loss: -1.8435 - val_accuracy: 0.8091
# Epoch 21/100
# 2124/2124 [==============================] - 20s 9ms/step - loss: -1.0037 - accuracy: 0.7919 - val_loss: -0.9716 - val_accuracy: 0.8030
# Epoch 22/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -1.7204 - accuracy: 0.7869 - val_loss: -1.7216 - val_accuracy: 0.8027
# Epoch 23/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -2.3865 - accuracy: 0.7874 - val_loss: -1.7925 - val_accuracy: 0.8079
# Epoch 24/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -1.6105 - accuracy: 0.7860 - val_loss: -1.2660 - val_accuracy: 0.8073
# Epoch 25/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -2.4120 - accuracy: 0.7916 - val_loss: -2.4633 - val_accuracy: 0.7885
# Epoch 26/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -2.1481 - accuracy: 0.7875 - val_loss: -2.4373 - val_accuracy: 0.8048
# Epoch 27/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -2.8010 - accuracy: 0.7879 - val_loss: -1.8324 - val_accuracy: 0.7950
# Epoch 28/100
# 2124/2124 [==============================] - 20s 9ms/step - loss: -2.9191 - accuracy: 0.7877 - val_loss: -2.2982 - val_accuracy: 0.8024
# Epoch 29/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: 2.3596 - accuracy: 0.7976 - val_loss: 4.7551 - val_accuracy: 0.7833
# Epoch 30/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: 1.0893 - accuracy: 0.7915 - val_loss: 0.2038 - val_accuracy: 0.7568
# Epoch 31/100
# 2124/2124 [==============================] - 18s 9ms/step - loss: -2.1791 - accuracy: 0.7781 - val_loss: -2.1474 - val_accuracy: 0.8083
# Epoch 32/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: -3.1526 - accuracy: 0.7881 - val_loss: -2.0105 - val_accuracy: 0.8081
# Epoch 33/100
# 2124/2124 [==============================] - 20s 9ms/step - loss: -1.6542 - accuracy: 0.7926 - val_loss: 13.3500 - val_accuracy: 0.8093
# Epoch 34/100
# 2124/2124 [==============================] - 20s 10ms/step - loss: 14.0072 - accuracy: 0.8062 - val_loss: 17.7799 - val_accuracy: 0.8086
# Epoch 35/100
# 2124/2124 [==============================] - 19s 9ms/step - loss: 16.9163 - accuracy: 0.8079 - val_loss: 15.9601 - val_accuracy: 0.8091
# Epoch 35: early stopping

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

def c_report(y_true, y_pred):
   print("Classification Report")
   print(classification_report(y_true, y_pred))
   acc_sc = accuracy_score(y_true, y_pred)
   print("Accuracy : "+ str(acc_sc))
   return acc_sc

def plot_confusion_matrix(y_true, y_pred):
   mtx = confusion_matrix(y_true, y_pred)
   sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,
               cmap="Blues", cbar=False)
   plt.ylabel('True label')
   plt.xlabel('Predicted label')

# %% [markdown]
# **Model Predicted for test dataset.**
#
# **Classification report and Confusion Matrix generated**

# %%
preds = (gru_model.predict(padded_test) > 0.5).astype("int32")
# Out:
# 531/531 [==============================] - 2s 3ms/step

# %%
c_report(y_test, preds)
#GRU
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.48      0.01      0.03      2108
#            1       0.81      1.00      0.89     13747
#            2       0.00      0.00      0.00      1132
#
#     accuracy                           0.81     16987
#    macro avg       0.43      0.34      0.31     16987
# weighted avg       0.71      0.81      0.73     16987
#
# Accuracy : 0.80914817213163
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.80914817213163

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, preds)
print(cm)
# Out:
# [[   29  2079     0]
#  [   31 13716     0]
#  [    1  1131     0]]

# %%
plot_confusion_matrix(y_test, preds)

# %% [markdown]
# **Save the model and the tokenizer (picle package helps us to save the tokenizer to use it on new messages)**

# %%
gru_model.save("GRUReviewRelevence_model")
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: GRUReviewRelevence_model/assets
# INFO:tensorflow:Assets written to: GRUReviewRelevence_model/assets

# %%
import pickle
with open('GRUReviewRelevence_model/tokenizer.pkl', 'wb') as output:
   pickle.dump(t, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# **Load the model and the tokenizer and predict whether the new message is a relevent / iirelevent

# %%
import tensorflow as tf

s_model = tf.keras.models.load_model("ReviewRelevence_model")
with open('GRUReviewRelevence_model/tokenizer.pkl', 'rb') as input:
    tokenizer = pickle.load(input)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

sms = ["Lottery won. You are given a free credit card offer with no emi for first month. call 7654437862 to claim your offer"]
#sms = ["hello! how are you? im visiting mom next week"]
sms_proc = t.texts_to_sequences(sms)
sms_proc = pad_sequences(sms_proc, maxlen=max_length, padding='post')
pred = (gru_model.predict(sms_proc)>0.5).astype("int32").item()
print(pred)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=378be7ce-053e-4e53-a8d7-d43f011c835b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
