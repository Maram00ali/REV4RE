# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Feb  2 05:42:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !pip install sklearn-evaluation
# !pip install scikit-plot
# !pip install scipy==1.11.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 58.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ...

# %%
# !pip install tensorboardx
#!pip install transformers==4.30.2
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.1 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 120.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 122.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.3 MB/s eta 0:00:00
# ...

# %%
# !pip install nltk

# %%
import torch
device = torch.device("cuda")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load the dataset
import pandas as pd
df=pd.read_csv("/content/drive/My Drive/Labled Dataset /REV4RE Dataset.csv",usecols= ["Review","RivewRelevance"])
#df["RivewRelevance"]=df["RivewRelevance"].replace({"irrelevant":0,"explicit":1,"implicit":2})
print("Data size:",len(df))
df.head()
# Out:
# Data size: 84721
#                                               Review RivewRelevance
# 0                                    5 star good app     irrelevant
# 1                A monthly subscription fee. Really?     irrelevant
# 2  Able to customize and decorate a ton of things...       explicit
# 3           All I can say is this game is the best!!       implicit
# 4  Although not the best, it better for own creat...       implicit

# %%
def get_label_num(label):
    if label == 'irrelevant':
        return 0
    elif label == 'explicit':
        return 1
    else:
        return 2

# %%
df['RivewRelevance'] = df['RivewRelevance'].apply(get_label_num)
df
# Out:
#                                                   Review  RivewRelevance
# 0                                        5 star good app               0
# 1                    A monthly subscription fee. Really?               0
# 2      Able to customize and decorate a ton of things...               1
# 3               All I can say is this game is the best!!               2
# 4      Although not the best, it better for own creat...               2
# ...                                                  ...             ...
# 84716  You won't regret !!!! Very convenient and usef...               1
# 84717  Your app sucks.Im deleting it.I know I'm not g...               1
# 84718  Your app wait along the process of downloads a...               1
# 84719  Your customer service is the most unresponsive...               2
# 84720  Your new desktop version sucks. I can save or ...               1
#
# [84721 rows x 2 columns]

# %%
df['RivewRelevance'].value_counts()
# Out:
# RivewRelevance
# 1    66187
# 0    11396
# 2     7138
# Name: count, dtype: int64

# %%
print(df['RivewRelevance'].value_counts())
# Random resampling
from sklearn.utils import resample

#Perform random undersampling on the majority class
# Split the dataset into classes
majority_class = df[df['RivewRelevance'] == df['RivewRelevance'].mode()[0]]  # majority class
minority_classes = df[df['RivewRelevance'] != df['RivewRelevance'].mode()[0]]  # minority classes

# Randomly undersample the majority class
majority_class_undersampled = resample(majority_class,
                                       replace=False,    # Don't allow replacement
                                       n_samples=len(minority_classes),  # Set to the size of the minority class
                                       random_state=42)  # Set random seed for reproducibility

# Step 4: Combine the undersampled majority class with the minority classes
df_balanced = pd.concat([majority_class_undersampled, minority_classes])

# Step 5: Shuffle the dataset
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Check the new class distribution
print(df_balanced['RivewRelevance'].value_counts())
# Out:
# RivewRelevance
# 1    66187
# 0    11396
# 2     7138
# Name: count, dtype: int64
# RivewRelevance
# 1    18534
# 0    11396
# 2     7138
# Name: count, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import tensorflow as tf

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42) # For CUDA
tf.random.set_seed(42)

# %%
import nltk
from nltk.corpus import stopwords
from nltk import *

# %%
 nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#pre_processing
#Running the Preprocessing and cleaning phase as well as the TFIDF Vectorization

import re
#Removes Punctuations
def remove_punctuations(data):
    punct_tag=re.compile(r'[^\w\s]')
    data=punct_tag.sub(r'',data)
    return data

#Removes HTML syntaxes
def remove_html(data):
    html_tag=re.compile(r'<.*?>')
    data=html_tag.sub(r'',data)
    return data

#Removes URL data
def remove_url(data):
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data

#Removes Emojis
def remove_emoji(data):
    emoji_clean= re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    data=emoji_clean.sub(r'',data)
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data

#Lemmatize the corpus
def lemma_traincorpus(data):
    lemmatizer=WordNetLemmatizer()
    out_data=""
    for words in data:
        out_data+= lemmatizer.lemmatize(words)
    return out_data

def tfidf(data):
    tfidfv = TfidfVectorizer(stop_words='english', ngram_range=(1, 2), lowercase=True, max_features=150000)
    fit_data_tfidf=tfidfv.fit_transform(data)
    return fit_data_tfidf

#df['Review']=df['Review'].apply(lambda z: remove_punctuations(z))
#df['Review']=df['Review'].apply(lambda z: remove_html(z))
#df['Review']=df['Review'].apply(lambda z: remove_url(z))
#df['Review']=df['Review'].apply(lambda z: remove_emoji(z))
#df['Review']=df['Review'].apply(lambda z: lemma_traincorpus(z))

# %%
# Declaring function for text preprocessing

def preprocess_text(main_df):
  df_1 = main_df.copy()

  # remove stopwords
  nltk.download('stopwords')         # Downloading stopwords
  stop = stopwords.words('english')
  df_1['Review'] = df_1['Review'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

  # remove punctuations and convert to lower case
  #df_1['Review'] = df_1['Review'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))

  # remove double spaces
 # df_1['Review'] = df_1['Review'].apply(lambda x: re.sub(' ', ' ', x))

  return df_1

# %%
#df= preprocess_text(df)

# %%
#df

# %%
# Function to perform all EDA
def perform_eda(df, name=""):
    # Printing basic detail of data like name, size, shape
    print(f"EDA of {str(name)} Data....")
    print(f"Size {df.size}")
    print(f"Columns {df.shape[1]}")
    print(f"Records {df.shape[0]}")
    print("="*50)

    # Printing top 5 records of data
    print("First Look of Data....")
    display(df.head())
    print("="*50)

    # Getting Numerical and Categorical columns Separately
    cat_cols = df.select_dtypes(np.object).columns
    num_cols = df.select_dtypes(np.number).columns

    # Printing the Numerical columns
    print("Dataset has following Numerical columns...")
    for i, j in enumerate(num_cols):
        print(f" {i+1}) {j}")

    # Printing the Categorical columns
    print("\n\nDataset has following Categorical columns...")
    for i, j in enumerate(cat_cols):
        print(f" {i+1}) {j}")

    # Printing info of data like data type, non null values
    print("="*50)
    print("Information of Data....")
    print(df.info())
    print("="*50)

# %%
#perform_eda(df)

# %%
from sklearn.model_selection import train_test_split

# %%
# Importing train test splilt library
from sklearn.model_selection import train_test_split

#train_df, eval_df = train_test_split(df, test_size = 0.20)
train_df, eval_df = train_test_split(df_balanced, test_size = 0.20) # with balnaced df

#test_df, eval_df = train_test_split(eval_df, test_size = 0.50)

# %%
# Train and test data dimensions
train_df.shape, eval_df.shape #,test_df.shape
# Out:
# ((29654, 2), (7414, 2))

# %%
# Compute class weights
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
# Compute class weights
labels = train_df['RivewRelevance'].dropna()
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
# Convert to a PyTorch tensor
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float)
print("Class Weights:", class_weights_tensor)
# Out:
# Class Weights: tensor([1.0846, 0.6673, 1.7257])

# %%
from simpletransformers.classification import ClassificationModel

# Create a ClassificationModel
#model = ClassificationModel('bert', 'bert-base-uncased', num_labels=3)
model = ClassificationModel('roberta', 'roberta-base',num_labels=3)
#model = ClassificationModel('roberta', 'roberta-large', num_labels=3)
#model = ClassificationModel('xlnet', 'xlnet-base-cased', num_labels=3)
#model = ClassificationModel('xlnet', 'xlnet-large-cased', num_labels=3)
#model = ClassificationModel('distilbert', 'distilbert-base-uncased', num_labels=3)
#model = ClassificationModel('albert', 'albert-base-v2', num_labels=3)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# ...

# %%
import os
train_args = {
    "output_dir": "outputs/",
    "cache_dir": "cache_dir/",
    "fp16": True,
    "fp16_opt_level": "O1",
    "max_seq_length": 512,
    "train_batch_size": 8,
    "gradient_accumulation_steps": 4,
    "eval_batch_size": 8,
    "num_train_epochs": 2 ,
    "weight_decay": 0,
    "learning_rate": 5e-5,
    "warmup_steps": 0,
    "logging_steps": 50,
    "save_steps": 700,
    "use_early_stopping": True,  # Keep early stopping enabled
    "model_args.early_stopping_delta": 0.01,  # Keep delta as is or adjust as needed
    "early_stopping_metric": "eval_loss",  # Change from "acc" to "eval_loss" to monitor validation loss
    "early_stopping_metric_minimize": True,  # Set to True because you want to minimize validation loss
    "early_stopping_patience": 2,  # Number of evaluation steps with no improvement before stopping
    "evaluate_during_training_steps": 500,  # Frequency of evaluation during training
    "overwrite_output_dir": True,
    "reprocess_input_data": False,
    "evaluate_during_training": True,  # Change to True to enable evaluation during training
    "evaluation_strategy": 'steps',  # Change to 'steps' to evaluate at regular steps
    "use_multiprocessing": False,
    "use_multiprocessing_for_evaluation":False,
    "process_count": os.cpu_count() - 2 if os.cpu_count() > 2 else 1,
    "n_gpu": 1,
    'use_cuda':True,


} #"weight": class_weights_tensor.tolist(),

# %%
#model = ClassificationModel('bert', 'bert-base-uncased', num_labels=3, args=train_args)
#model = ClassificationModel('roberta', 'roberta-large', num_labels=3, args=train_args)
model = ClassificationModel('roberta', 'roberta-base', num_labels=3, args= train_args)
#model = ClassificationModel('xlnet', 'xlnet-base-cased', num_labels=3, args=train_args)
#model = ClassificationModel('xlnet', 'xlnet-large-cased',num_labels=3, args=train_args)
#model = ClassificationModel('distilbert', 'distilbert-base-uncased', num_labels=3, args=train_args)
#model = ClassificationModel('albert', 'albert-base-v2', num_labels=3, args=train_args)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Train the model
model.train_model(train_df, eval_df=eval_df)
import sklearn

from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score

#model.train_model(train_df, acc=sklearn.metrics.accuracy_score)

#model.eval_model(eval_df, acc=sklearn.metrics.accuracy_score)
# Out:
# /usr/local/lib/python3.11/dist-packages/simpletransformers/classification/classification_model.py:610: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/simpletransformers/classification/classification_model.py:882: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# Running Epoch 1 of 2:   0%|          | 0/3707 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/simpletransformers/classification/classification_model.py:905: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# ...

# %%
result, model_outputs, wrong_predictions = model.eval_model(eval_df, multi_label=False, output_dir=None)
print("Evaluation Results:", result)
# Out:
# /usr/local/lib/python3.11/dist-packages/simpletransformers/classification/classification_model.py:1453: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# ...

# %%
from sklearn.metrics import f1_score, accuracy_score

# Define custom F1-multiclass metric
def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='micro')

# Evaluate the model with custom metrics
result, model_outputs, wrong_predictions = model.eval_model(
    eval_df,
    f1=f1_multiclass,
    acc=accuracy_score
)

print("Evaluation Results:", result)
# Out:
# /usr/local/lib/python3.11/dist-packages/simpletransformers/classification/classification_model.py:1453: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# ...

# %%
from sklearn.metrics import classification_report

# Optional: Use `classification_report` for more detailed evaluation
eval_labels = eval_df["RivewRelevance"].values  # Replace with your label column name
predicted_labels = [np.argmax(output) for output in model_outputs]

print(f"Number of evaluation labels: {len(eval_labels)}")
print(f"Number of predicted labels: {len(predicted_labels)}")




#print("\nClassification Report:")
#print(classification_report(eval_labels, predicted_labels))
# Out:
# Number of evaluation labels: 7414
# Number of predicted labels: 7414

# %%
eval_df = eval_df.dropna().reset_index(drop=True)
eval_texts = eval_df["Review"].values.tolist()  # Ensure this matches eval_labels
eval_labels = eval_df["RivewRelevance"].values

# %%
#min_length = min(len(eval_labels), len(predicted_labels))
#eval_labels = eval_labels[:min_length]
#predicted_labels = predicted_labels[:min_length]

# %%
print("\nClassification Report:")
print(classification_report(eval_labels, predicted_labels))
## evalution dataset without test dataset with Random under sampling Distlbert
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      2282
#            1       0.81      0.87      0.84      3722
#            2       0.68      0.54      0.60      1410
#
#     accuracy                           0.79      7414
#    macro avg       0.76      0.74      0.75      7414
# weighted avg       0.78      0.79      0.78      7414

# %%
from sklearn.metrics import confusion_matrix

# predicted_labels is already a 1D array
cm = confusion_matrix(eval_labels, predicted_labels)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[1849  311  122]
#  [ 257 3222  243]
#  [ 181  461  768]]

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

y_true = eval_df['RivewRelevance']
y_probas = model_outputs
skplt.metrics.plot_roc_curve(y_true, y_probas)
plt.show()

## evalution dataset without test dataset with random under sampling Distlbert
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:95: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
#eval_df = eval_df.reset_index(drop=True)
#model_outputs, raw_outputs = model.predict(eval_df["Review"].values.tolist())

# %% [markdown]
# Evaluation on test dataset

# %%
test_texts = test_df["Review"].values.tolist()  # Ensure 'Review' column contains text data
test_labels = test_df["RivewRelevance"].values  # Ensure correct column name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-beaeb635976a> in <cell line: 0>()
# ----> 1 test_texts = test_df["Review"].values.tolist()  # Ensure 'Review' column contains text data
#       2 test_labels = test_df["RivewRelevance"].values  # Ensure correct column name
#       3
#
# NameError: name 'test_df' is not defined

# %%
predicted_labels, raw_outputs = model.predict(test_texts[:len(test_labels)])

# %%
print(f"Number of predictions: {len(predicted_labels)}")

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Generate classification report
print("\nClassification Report:")
print(classification_report(test_labels, predicted_labels))

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(test_labels, predicted_labels))

### test dataset albert-base-v2

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, np.argmax(raw_outputs, axis = 1))
print(cm)

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

y_true = test_df['RivewRelevance']
y_probas = raw_outputs
skplt.metrics.plot_roc_curve(y_true, y_probas)
plt.show()
## test dataset albert-base-v2
